# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('2014_2019_Philadelphia_campaign_contributions.xlsx')
df.describe()
# Out:
#               Amount  BuildingRealEstateFlag  CharterPrivateSchoolFlag  \
# count   41140.000000                  7983.0                     399.0
# mean      797.867825                     1.0                       1.0
# std      3358.977329                     0.0                       0.0
# min         0.000000                     1.0                       1.0
# 25%       100.000000                     1.0                       1.0
# 50%       250.000000                     1.0                       1.0
# 75%      1000.000000                     1.0                       1.0
# max    400000.000000                     1.0                       1.0
#
#        FoodBeverageTobaccoFlag  LawFlag  CorporateFlag  LobbyingFlag
# count                   1252.0   5263.0          609.0         619.0
# mean                       1.0      1.0            1.0           1.0
# std                        0.0      0.0            0.0           0.0
# ...

# %%
df.head()
# Out:
#          Donor Name Original         Donor Name Cleaned  \
# 0               Steven Clark               Steven Clark
# 1  1 RFP Limited Partnership  1 RFP Limited Partnership
# 2          1014 INVESTORS LP          1014 INVESTORS LP
# 3                      1199c         District 1199C PAC
# 4                      1199c         District 1199C PAC
#
#           Contribution To  Amount       Date Sector (grouped)  \
# 0         Al Taubenberger   250.0 2019-04-01              NaN
# 1  Anthony Hardy Williams  2500.0 2014-09-29          Unknown
# 2         Cherelle Parker   500.0 2014-10-31          Unknown
# 3           Isaiah Thomas   700.0 2014-04-23           Unions
# 4           Isaiah Thomas   500.0 2014-08-07           Unions
#
#     Sector (more detailed)  BuildingRealEstateFlag  CharterPrivateSchoolFlag  \
# 0                      NaN                     NaN                       NaN
# 1  Unknown or Undetermined                     NaN                       NaN
# ...
