# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import wavfile

# %%
sample_rate, data = wavfile.read('StarWars3.wav')

# %%
sample_rate
# Out:
# 22050

# %%
plt.plot(data)
# Out:
# Exception ignored in: <function Wave_write.__del__ at 0x7f4381ad0ee0>
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/wave.py", line 327, in __del__
#     self.close()
#   File "/usr/lib/python3.8/wave.py", line 445, in close
#     self._ensure_header_written(0)
#   File "/usr/lib/python3.8/wave.py", line 468, in _ensure_header_written
#     self._write_header(datasize)
#   File "/usr/lib/python3.8/wave.py", line 472, in _write_header
#     self._file.write(b'RIFF')
# ValueError: I/O operation on closed file.
# Exception ignored in: <function Wave_write.__del__ at 0x7f4381ad0ee0>
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/wave.py", line 327, in __del__
#     self.close()
#   File "/usr/lib/python3.8/wave.py", line 445, in close
#     self._ensure_header_written(0)
#   File "/usr/lib/python3.8/wave.py", line 468, in _ensure_header_written
#     self._write_header(datasize)
#   File "/usr/lib/python3.8/wave.py", line 472, in _write_header
#     self._file.write(b'RIFF')
# ValueError: I/O operation on closed file.

# %%
import IPython.display as ipd
ipd.Audio(data=data, rate=sample_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
class MyList(object):
    def __init__(self, items):
        self.items = items
    def _repr_html_(self):
        str = '<ul>'
        for item in self.items:
            str += f'<li>{item}</li>'
        str += '</ul>'
        return str

# %%
MyList(['foo', 'bar', 'baz'])
# Out:
# <ul><li>foo</li><li>bar</li><li>baz</li></ul>

# %%
ipd.YouTubeVideo('YNEEysghKQo')

# %%
squeaky = data[::4]
ipd.Audio(data=squeaky, rate=sample_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
i
